# %%
import pandas as pd

# %%
car = pd.read_csv('CarPrice_Assignment.csv')
car
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
car_price = car.copy()
car_price
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
car_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
car_price = car_price[['CarName', 'fueltype', 'doornumber', 'carbody', 'carbody', 'enginelocation', 'wheelbase', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']]
car_price
# Out:
#                       CarName fueltype doornumber      carbody      carbody  \
# 0          alfa-romero giulia      gas        two  convertible  convertible
# 1         alfa-romero stelvio      gas        two  convertible  convertible
# 2    alfa-romero Quadrifoglio      gas        two    hatchback    hatchback
# 3                 audi 100 ls      gas       four        sedan        sedan
# 4                  audi 100ls      gas       four        sedan        sedan
# ..                        ...      ...        ...          ...          ...
# 200           volvo 145e (sw)      gas       four        sedan        sedan
# 201               volvo 144ea      gas       four        sedan        sedan
# 202               volvo 244dl      gas       four        sedan        sedan
# 203                 volvo 246   diesel       four        sedan        sedan
# 204               volvo 264gl      gas       four        sedan        sedan
#
# ...

# %%
car_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CarName           205 non-null    object
#  1   fueltype          205 non-null    object
#  2   doornumber        205 non-null    object
#  3   carbody           205 non-null    object
#  4   carbody           205 non-null    object
#  5   enginelocation    205 non-null    object
#  6   wheelbase         205 non-null    float64
#  7   wheelbase         205 non-null    float64
#  8   carlength         205 non-null    float64
#  9   carwidth          205 non-null    float64
#  10  carheight         205 non-null    float64
#  11  curbweight        205 non-null    int64
#  12  enginetype        205 non-null    object
#  13  cylindernumber    205 non-null    object
#  14  enginesize        205 non-null    int64
#  15  fuelsystem        205 non-null    object
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline, make_pipeline

# display pipeline
from sklearn import set_config
set_config(display='diagram')

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(car_price.drop(columns=['price']), car_price['price'], test_size = 0.2, random_state=42)

# %%
transformerOHE = ColumnTransformer([
    ('ohe', OneHotEncoder(sparse=False, handle_unknown='ignore'), [0,1,2,3,4,5,12,13,15])
], remainder='passthrough')

# %%
lr = LinearRegression()

# %%
pipe = Pipeline([
    ('ohe', transformerOHE),
    ('lr', lr)
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('ohe',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   [0, 1, 2, 3, 4, 5, 12, 13,
#                                                    15])])),
#                 ('lr', LinearRegression())])

# %%
y_pred = pipe.predict(X_test)
y_pred
# Out:
# array([15240.23424254, 21337.80788806, 10772.40341425, 11647.71919408,
#        24746.27545687,  6580.47346159,  8846.84732718,  8314.17851813,
#        11743.99784614,  7593.22126837, 16910.98659336,  6393.23129739,
#        17032.35272255,  8989.93626175, 42508.21677566,  6629.33345042,
#        -1880.52255043, 13140.63147204, 13090.94768262, 13421.67116059,
#        10859.99813426, 15835.4041766 ,  8377.19766268,  5274.61822632,
#        11228.08487391, 17125.04971913, 12320.33706664, 15812.47738647,
#         4882.39905608, 13974.39314307, 25407.24345415,  5543.15176033,
#         4077.82490488, 18109.12064311,  7208.79514346, 26135.69826234,
#        13686.75376707,  9403.6799742 , 10499.6690448 , 14752.4048921 ,
#         9718.66575869])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 2848.436134141256
